# %% [markdown]
# # 1. Import Library & Package

# %%
# !pip install google_play_scraper
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 3.4 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
pd.options.mode.chained_assignment = None
import csv
import numpy as np

from google_play_scraper import Sort, reviews, reviews_all
from itertools import count

# %% [markdown]
# # 2. Scarping Data dari Playstore App Cici: Asisten AI Cerdas
#
# ---
# Aplikasi Cici merupakan aplikasi asisten AI yang dapat digunakan untuk pekerjaan, belajar, dan mencari ide kreatif.
#
# ---
# Melakukan scraping data pada review aplikasi Cici: Asisten AI Cerdas di playstore

# %%
result, continual_token = reviews(
    'com.larus.wolf',
    lang='id',
    country='id',
    sort=Sort.NEWEST,
    count=12000,
    filter_score_with=None
)

df = pd.DataFrame(np.array(result),columns=['review'])
df = df.join(pd.DataFrame(df.pop('review').tolist()))
df
# Out:
#                                    reviewId         userName  \
# 0      03886b9c-6a14-4e77-84a3-103bb2c8f301  Pengguna Google
# 1      297938a9-894e-4637-84b4-a6bcec2eb6fa  Pengguna Google
# 2      e65a8526-d821-4976-807e-c44d3f0c8a41  Pengguna Google
# 3      749311a0-35bd-43a2-8381-b0b0162cb65a  Pengguna Google
# 4      9ae46c67-e82d-4d5f-991e-b947f8cfad70  Pengguna Google
# ...                                     ...              ...
# 11995  cbf582c3-d095-4047-b219-45b5482115ae  Pengguna Google
# 11996  f898e822-b03a-4258-85b1-f2ee67d35821  Pengguna Google
# 11997  80642fdc-7995-490c-85af-2e35393ed7c7  Pengguna Google
# 11998  c857c846-8b55-49b8-bf6f-0dacd1b29cc0  Pengguna Google
# 11999  15519b71-7e4b-4378-8301-a35624eee97e  Pengguna Google
#
#                                                userImage  \
# 0      https://play-lh.googleusercontent.com/EGemoI2N...
# 1      https://play-lh.googleusercontent.com/EGemoI2N...
# 2      https://play-lh.googleusercontent.com/EGemoI2N...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              12000 non-null  object
#  1   userName              12000 non-null  object
#  2   userImage             12000 non-null  object
#  3   content               12000 non-null  object
#  4   score                 12000 non-null  int64
#  5   thumbsUpCount         12000 non-null  int64
#  6   reviewCreatedVersion  6449 non-null   object
#  7   at                    12000 non-null  datetime64[ns]
#  8   replyContent          1 non-null      object
#  9   repliedAt             1 non-null      datetime64[ns]
#  10  appVersion            6449 non-null   object
# dtypes: datetime64[ns](2), int64(2), object(7)
# memory usage: 1.0+ MB

# %% [markdown]
# # 3. Cleaning Dataset
#
# Melakukan beberapa metode pembersihan sederhana untuk dataset scraping

# %%
new_df = df[['reviewId', 'userName', 'score', 'content', 'thumbsUpCount', 'at']]
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   reviewId       12000 non-null  object
#  1   userName       12000 non-null  object
#  2   score          12000 non-null  int64
#  3   content        12000 non-null  object
#  4   thumbsUpCount  12000 non-null  int64
#  5   at             12000 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(2), object(3)
# memory usage: 562.6+ KB

# %%
clean_df = new_df.dropna()
clean_df = clean_df.drop_duplicates()
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   reviewId       12000 non-null  object
#  1   userName       12000 non-null  object
#  2   score          12000 non-null  int64
#  3   content        12000 non-null  object
#  4   thumbsUpCount  12000 non-null  int64
#  5   at             12000 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(2), object(3)
# memory usage: 562.6+ KB

# %% [markdown]
# # 4. Saving Dataset to CSV

# %%
clean_df.to_csv('cici_reviews.csv', index=False)

# %% [markdown]
# End Code.
